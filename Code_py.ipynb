# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image

# %%
content_path =r"C:\Users\hp\Downloads\Python\cont"
style_path = r"C:\Users\hp\Downloads\Python\sty"

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg") :
            img_path = os.path.join(folder, filename)
            img = Image.open(img_path)
            img = img.resize((256,256))
            img = img.convert('RGB')
            img = np.array(img)
            images.append(img)
            img = img / 255.0
    
    images = np.array(images)
    return images

# %%
target = load_images_from_folder(content_path)
style = load_images_from_folder(style_path)

# %%
from keras.applications.vgg19 import VGG19
model = VGG19(weights = 'imagenet',include_top=False,input_shape=(256,256,3))

# %%
model.trainable = False

# %%
model_layers=[]
for layer in model.layers:
    model_layers.append(layer.name)
print(model_layers)

model.get_layer('block5_conv4').output
# Out:
# ['input_layer', 'block1_conv1', 'block1_conv2', 'block1_pool', 'block2_conv1', 'block2_conv2', 'block2_pool', 'block3_conv1', 'block3_conv2', 'block3_conv3', 'block3_conv4', 'block3_pool', 'block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_conv4', 'block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool']
# <KerasTensor shape=(None, 16, 16, 512), dtype=float32, sparse=False, name=keras_tensor_20>

# %%
style_layers= [('block1_conv1',0.2),('block2_conv1',0.2),('block3_conv1',0.2), ('block4_conv1',0.2),('block5_conv1',0.2)]

# %%
def content_cost(content_image_model_output, generated_image_model_output):
    a_content= content_image_model_output[-1]
    a_generated= generated_image_model_output[-1]
    m,n_H,n_W,n_C= a_generated.get_shape().as_list()
    a_content_unrolled = tf.reshape(a_content,[m,-1,n_C])
    a_generated_unrolled = tf.reshape(a_generated,[m,-1,n_C])
    J_content= (1/(4*n_H*n_W*n_C))* tf.reduce_sum(tf.square(tf.subtract(a_content_unrolled,a_generated_unrolled)))
    return J_content

# %%
def gram_matrix(M):
    Gram_matrix= tf.matmul(M, tf.transpose(M))
    return Gram_matrix

# %%
def one_layer_style_cost(a_style_layer, a_generated_layer):
    m, n_H, n_W, n_C= a_generated_layer.get_shape().as_list()
    a_style_layer= tf.transpose(tf.reshape(a_style_layer,[-1,n_C]),[1,0])
    a_generated_layer= tf.transpose(tf.reshape(a_generated_layer,[-1,n_C]), [1,0])
    gram_style = gram_matrix(a_style_layer)
    gram_gen= gram_matrix(a_generated_layer)
    J_style_layer= (1/(4*n_C**2*(n_H*n_W)**2))*tf.reduce_sum(tf.square(tf.subtract(gram_style,gram_gen)))
    return J_style_layer

# %%
def style_cost(style_image_model_output, generated_image_model_output, style_layers= style_layers):
    J_style= 0
    style_activations= style_image_model_output[1:]
    generated_activations= generated_image_model_output[1:]
    num_layers = len(style_activations)
    
    for i, tuple_name_weight in zip(range(num_layers), style_layers):
        style_cost_layer= one_layer_style_cost(style_activations[i],generated_activations[i])
        style_cost_layer *= tuple_name_weight[1]
        J_style += style_cost_layer
    return J_style

# %%
def total_cost(J_content,J_style,alpha=10, beta=40):
    J_total= alpha* J_content + beta* J_style
    return J_total

# %%
def mini_vgg19(layers):
    model = VGG19(include_top=False, weights='imagenet')
    mini_model_outputs = [model.get_layer(layer_weight[0]).output for layer_weight in layers]
    
    mini_model = tf.keras.Model(inputs=model.input, outputs=mini_model_outputs)
    return mini_model

# %%
s_image = style[0]

# %%
style_image_arr= np.array(s_image)
plt.imshow(style_image_arr)

# %%
arr_style_image =tf.image.random_crop(style_image_arr,[256,256, 3]) 
style_image= tf.constant(np.reshape(arr_style_image.numpy(),(1,)+(256,256,3)))
print(style_image.shape)
# Out:
# (1, 256, 256, 3)

# %%
t_image = target[0]

# %%
content_image_arr= np.array(t_image)
content_image_arr_reshaped= np.reshape(content_image_arr, ((1,)+ content_image_arr.shape))
print(content_image_arr_reshaped.shape)
content_image= tf.constant(content_image_arr_reshaped)
plt.imshow(content_image_arr)
# Out:
# (1, 256, 256, 3)

# %%
generated_image = tf.Variable(tf.image.convert_image_dtype(content_image, tf.float32))

# %%
content_layer= [('block5_conv4',1)]
mini_vgg19_model= mini_vgg19(style_layers+ content_layer)

# %%
content_image= tf.Variable(tf.image.convert_image_dtype(content_image, tf.float32))
style_image= tf.Variable(tf.image.convert_image_dtype(style_image, tf.float32))

C_list_vgg19_encoders= mini_vgg19_model(content_image)
S_list_vgg19_encoders= mini_vgg19_model(style_image)
G_list_vgg19_encoders= mini_vgg19_model(generated_image)

# %%
def tensor_to_image(tensor):
    tensor = tensor * 255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor) > 3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    return Image.fromarray(tensor)

# %%
opt = tf.optimizers.Adam(learning_rate=0.001, beta_1=0.99, epsilon=1e-1)

# %%
def clip_0_1(image):
    return tf.clip_by_value(image, clip_value_min=0.0, clip_value_max=1.0)

# %%
def train_step_one(image, loss_history):
    with tf.GradientTape() as tape:
        aciv_G = mini_vgg19_model(image)
        J_content = content_cost(C_list_vgg19_encoders, aciv_G)
        J_style = style_cost(S_list_vgg19_encoders, aciv_G, style_layers)
        J_total = total_cost(J_content, J_style)
        loss_history.append(J_total.numpy())
   
    grad = tape.gradient(J_total, image)
    opt.apply_gradients([(grad, image)])
    image.assign(clip_0_1(image))

# %%
import time

start = time.time()
epochs = 40
steps_per_epoch = 100
step = 0
loss_history = []

for i in range(epochs):
    for j in range(steps_per_epoch):
        step += 1
        train_step_one(generated_image, loss_history)

print("Train step: {}".format(step))
image = tensor_to_image(generated_image)
end = time.time()
print("Total time: {:.1f}".format(end - start))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 12
#      10     for j in range(steps_per_epoch):
#      11         step += 1
# ---> 12         train_step_one(generated_image, loss_history)
#      14 print("Train step: {}".format(step))
#      15 image = tensor_to_image(generated_image)
#
# Cell In[26], line 3, in train_step_one(image, loss_history)
#       1 def train_step_one(image, loss_history):
#       2     with tf.GradientTape() as tape:
# ----> 3         aciv_G = mini_vgg19_model(image)
#       4         J_content = content_cost(C_list_vgg19_encoders, aciv_G)
#       5         J_style = style_cost(S_list_vgg19_encoders, aciv_G, style_layers)
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\keras\src\layers\layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\keras\src\ops\operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File D:\Anaconda\Lib\site-packages\keras\src\models\functional.py:202, in Functional.call(self, inputs, training, mask)
#     200         if mask is not None:
#     201             x._keras_mask = mask
# --> 202 outputs = self._run_through_graph(
#     203     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204 )
#     205 return unpack_singleton(outputs)
#
# File D:\Anaconda\Lib\site-packages\keras\src\ops\function.py:155, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     153     outputs = call_fn(op, *args, **kwargs)
#     154 else:
# --> 155     outputs = op(*args, **kwargs)
#     157 # Update tensor_dict.
#     158 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File D:\Anaconda\Lib\site-packages\keras\src\models\functional.py:592, in operation_fn.<locals>.call(*args, **kwargs)
#     586 if (
#     587     hasattr(operation, "_call_has_training_arg")
#     588     and operation._call_has_training_arg
#     589     and training is not None
#     590 ):
#     591     kwargs["training"] = training
# --> 592 return operation(*args, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\keras\src\layers\layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\keras\src\ops\operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File D:\Anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:243, in BaseConv.call(self, inputs)
#     242 def call(self, inputs):
# --> 243     outputs = self.convolution_op(
#     244         inputs,
#     245         self.kernel,
#     246     )
#     247     if self.use_bias:
#     248         if self.data_format == "channels_last":
#
# File D:\Anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:233, in BaseConv.convolution_op(self, inputs, kernel)
#     232 def convolution_op(self, inputs, kernel):
# --> 233     return ops.conv(
#     234         inputs,
#     235         kernel,
#     236         strides=list(self.strides),
#     237         padding=self.padding,
#     238         dilation_rate=self.dilation_rate,
#     239         data_format=self.data_format,
#     240     )
#
# File D:\Anaconda\Lib\site-packages\keras\src\ops\nn.py:909, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     905 if any_symbolic_tensors((inputs,)):
#     906     return Conv(strides, padding, data_format, dilation_rate).symbolic_call(
#     907         inputs, kernel
#     908     )
# --> 909 return backend.nn.conv(
#     910     inputs, kernel, strides, padding, data_format, dilation_rate
#     911 )
#
# File D:\Anaconda\Lib\site-packages\keras\src\backend\tensorflow\nn.py:255, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     251 if channels != kernel.shape[-2]:
#     252     # If kernel's in_channel does not match input's channels,  it indicates
#     253     # convolution is broken down into groups.
#     254     return _conv_xla()
# --> 255 return _conv()
#
# File D:\Anaconda\Lib\site-packages\keras\src\backend\tensorflow\nn.py:231, in conv.<locals>._conv()
#     229 def _conv():
#     230     tf_data_format = _convert_data_format(data_format, len(inputs.shape))
# --> 231     return tf.nn.convolution(
#     232         inputs,
#     233         kernel,
#     234         strides,
#     235         padding.upper(),
#     236         data_format=tf_data_format,
#     237         dilations=dilation_rate,
#     238     )
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\ops\nn_ops.py:1186, in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1176 @tf_export("nn.convolution", v1=[])
#    1177 @dispatch.add_dispatch_support
#    1178 def convolution_v2(  # pylint: disable=missing-docstring
#    (...)
#    1184     dilations=None,
#    1185     name=None):
# -> 1186   return convolution_internal(
#    1187       input,  # pylint: disable=redefined-builtin
#    1188       filters,
#    1189       strides=strides,
#    1190       padding=padding,
#    1191       data_format=data_format,
#    1192       dilations=dilations,
#    1193       name=name)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\ops\nn_ops.py:1319, in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1316   else:
#    1317     op = conv1d
# -> 1319   return op(
#    1320       input,
#    1321       filters,
#    1322       strides,
#    1323       padding=padding,
#    1324       data_format=data_format,
#    1325       dilations=dilations,
#    1326       name=name)
#    1327 else:
#    1328   if channel_index == 1:
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\ops\nn_ops.py:2793, in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2789 input_rank = input.shape.rank
#    2790 if input_rank is None or input_rank < 5:
#    2791   # We avoid calling squeeze_batch_dims to reduce extra python function
#    2792   # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2793   return gen_nn_ops.conv2d(
#    2794       input,
#    2795       filter=filters,
#    2796       strides=strides,
#    2797       padding=padding,
#    2798       data_format=data_format,
#    2799       dilations=dilations,
#    2800       name=name)
#    2801 return squeeze_batch_dims(
#    2802     input,
#    2803     functools.partial(
#    (...)
#    2810     inner_rank=3,
#    2811     name=name)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py:1345, in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1343   pass
#    1344 try:
# -> 1345   return conv2d_eager_fallback(
#    1346       input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#    1347       padding=padding, explicit_paddings=explicit_paddings,
#    1348       data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#    1349 except _core._SymbolicException:
#    1350   pass  # Add nodes to the TensorFlow graph.
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py:1434, in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1430 _inputs_flat = [input, filter]
#    1431 _attrs = ("T", _attr_T, "strides", strides, "use_cudnn_on_gpu",
#    1432 use_cudnn_on_gpu, "padding", padding, "explicit_paddings",
#    1433 explicit_paddings, "data_format", data_format, "dilations", dilations)
# -> 1434 _result = _execute.execute(b"Conv2D", 1, inputs=_inputs_flat, attrs=_attrs,
#    1435                            ctx=ctx, name=name)
#    1436 if _execute.must_record_gradient():
#    1437   _execute.record_gradient(
#    1438       "Conv2D", _inputs_flat, _attrs, _result)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.plot(loss_history)
plt.xlabel('Step')
plt.ylabel('Total Loss')
plt.title('Loss During Training')
plt.show()

# %%
image
